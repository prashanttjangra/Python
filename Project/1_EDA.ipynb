# %% [markdown]
# ## Exploratory Data Analysis for all Data Roles

# %% [markdown]
# ### Import Libraries and Data

# %%
# Importing libraries
import ast
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Loading dataset
df=pd.read_csv('C:/Users/Admin/Downloads/job_postings.csv')

# Data Cleanup
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])
df['job_skills']=df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else(x))

# %% [markdown]
# ### Roles to Explore

# %%
df_plot=df['job_title_short'].value_counts().head(10).to_frame()

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='job_title_short', legend=False)
sns.despine()
plt.title('Number of Data Jobs Around the World')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Countries to Explore

# %%
df_plot=df['job_country'].value_counts().head(15).to_frame()

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='job_country', legend=False)
sns.despine()
plt.title('Number of Jobs per Country')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Companies to Explore

# %%
df_plot=df['company_name'].value_counts().head(15).to_frame()

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='company_name', legend=False)
sns.despine()
plt.title('Number of Jobs per Company')
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Job Opportunities

# %%
dict_column={
    'job_no_degree_mention':'Degree Requirement',
    'job_work_from_home':'Work From Home Offered'
}

fig, ax=plt.subplots(1, 2, figsize=(9, 4))

for i,(column, title) in enumerate(dict_column.items()):
    ax[i].pie(df[column].value_counts(), labels=['False', 'True'], autopct='%1.1f%%', startangle=90)
    ax[i].set_title(title)

plt.show()
